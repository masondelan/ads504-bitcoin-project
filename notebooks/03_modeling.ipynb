# %% [markdown]
# # 03 · Modeling, Validation & Results
#
# **ADS 504 — Bitcoin Price Direction**
#
# Train and compare Logistic Regression, Random Forest, XGBoost, and LightGBM.

# %% [markdown]
# ## 1. Setup & load modeling table

# %% [markdown]
# ## 2. Train / test split
#
# Chronological split — **do not shuffle** time-series data. Hold out the most
# recent slice as the test set.

# %% [markdown]
# ## 3. Baseline
#
# Majority-class (and/or 'always up') baseline so 'better than guessing' is explicit.

# %% [markdown]
# ## 4. Models
#
# Train each model with `TimeSeriesSplit` cross-validation; tune key hyperparameters.
#
# - Logistic Regression
# - Random Forest
# - XGBoost
# - LightGBM

# %% [markdown]
# ## 5. Evaluation
#
# Accuracy, precision, recall, F1, ROC-AUC, and confusion matrices on the held-out
# test set.

# %% [markdown]
# ## 6. Model comparison
#
# Comparison table + plots across all models. Save figures to `../reports/figures/`.

# %% [markdown]
# ## 7. Findings
#
# Which model won and why, the challenges (leakage, class balance, non-stationarity),
# and what the results mean for the problem.
