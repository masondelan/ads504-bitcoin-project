# %% [markdown]
# # 01 · EDA & Pre-processing
#
# **ADS 504 — Bitcoin Price Direction**
#
# Load the raw BTCUSDT klines, clean them, and explore the data so we can decide
# how to model it. *Fill in the code cells under each section.*

# %% [markdown]
# ## 1. Setup
#
# Imports and configuration.

# %% [markdown]
# ## 2. Load the data
#
# Read the kline CSV(s) from `../data/`, assign column names, and parse the
# `open time` column to a datetime index. (See the README for the column layout.)

# %% [markdown]
# ## 3. Data quality
#
# - Missing values / gaps in the time series
# - Duplicate or out-of-order timestamps
# - Data types and ranges (human-error / sanity checks)

# %% [markdown]
# ## 4. Exploratory analysis
#
# Price and volume over time, distributions, rolling statistics, correlations.

# %% [markdown]
# ## 5. Outliers
#
# Identify and decide how to handle extreme returns / volume spikes.

# %% [markdown]
# ## 6. Notes & next steps
#
# Summarize what the data looks like and what pre-processing carries into
# `02_feature_engineering`.
